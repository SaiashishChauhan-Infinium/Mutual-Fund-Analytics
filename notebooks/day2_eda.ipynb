# %%
from pathlib import Path
import pandas as pd

files = list(Path(r"C:\Users\Saiashish\Desktop\Mutual-Fund-Analytics\data\raw").glob("*.csv"))

for file in files:
    try:
        df = pd.read_csv(file, nrows=5)

        print("\n" + "="*80)
        print(file.name)
        print("="*80)
        print(df.columns.tolist())

    except Exception as e:
        print(f"Error reading {file.name}: {e}")
# Out:
# ...
# 01_fund_master.csv
# ...
# ['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category', 'plan', 'launch_date', 'benchmark', 'expense_ratio_pct', 'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager', 'risk_category', 'sebi_category_code']
#
# ...
# 02_nav_history.csv
# ...
# ['amfi_code', 'date', 'nav']
#
# ...
# 03_aum_by_fund_house.csv
# ...
# ['date', 'fund_house', 'aum_lakh_crore', 'aum_crore', 'num_schemes']
#
# ...
# 04_monthly_sip_inflows.csv
# ...
# ['month', 'sip_inflow_crore', 'active_sip_accounts_crore', 'new_sip_accounts_lakh', 'sip_aum_lakh_crore', 'yoy_growth_pct']
#
# ...
# 05_category_inflows.csv
# ...
# ['month', 'category', 'net_inflow_crore']
#
# ...
# 06_industry_folio_count.csv
# ...
# ['month', 'total_folios_crore', 'equity_folios_crore', 'debt_folios_crore', 'hybrid_folios_crore', 'others_folios_crore']
#
# ...
# 07_scheme_performance.csv
# ...

# %%
import pandas as pd

benchmark = pd.read_csv(
    r"C:\Users\Saiashish\Desktop\Mutual-Fund-Analytics\data\processed\clean_benchmark_indices.csv"
)

print(benchmark["index_name"].unique())
# Out:
# ['NIFTY50' 'NIFTY100' 'NIFTY_MIDCAP150' 'BSE_SMALLCAP' 'NIFTY500'
#  'CRISIL_LIQUID' 'CRISIL_GILT']

# %%
import pandas as pd

nav = pd.read_csv(
    r"C:\Users\Saiashish\Desktop\Mutual-Fund-Analytics\data\processed\clean_nav_history.csv"
)

print(nav.head())

print(nav.shape)
# Out:
#    amfi_code        date       nav
# 0     100016  2022-01-03  520.4608
# 1     100016  2022-01-04  515.0971
# 2     100016  2022-01-05  521.7239
# 3     100016  2022-01-06  515.7880
# 4     100016  2022-01-07  515.1639
# (46000, 3)

# %%
import pandas as pd

funds = pd.read_csv(
    r"C:\Users\Saiashish\Desktop\Mutual-Fund-Analytics\data\processed\clean_fund_master.csv"
)

print(funds.shape)

print(funds["amfi_code"].nunique())
# Out:
# (40, 15)
# 40

# %%
import pandas as pd

aum = pd.read_csv(
    r"C:\Users\Saiashish\Desktop\Mutual-Fund-Analytics\data\processed\clean_aum_by_fund_house.csv"
)

print(aum.head())
print(aum.shape)

print("\nUnique Fund Houses:")
print(aum["fund_house"].unique()[:20])

print("\nDate Range:")
print(aum["date"].min())
print(aum["date"].max())
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168
# (90, 5)
#
# Unique Fund Houses:
# ['SBI Mutual Fund' 'ICICI Prudential MF' 'HDFC Mutual Fund'
#  'Nippon India MF' 'Kotak Mahindra MF' 'Aditya Birla Sun Life MF'
#  'Axis Mutual Fund' 'UTI Mutual Fund' 'Mirae Asset MF' 'DSP Mutual Fund']
#
# Date Range:
# 2022-03-31
# 2025-12-31

# %%
sip = pd.read_csv(
    r"C:\Users\Saiashish\Desktop\Mutual-Fund-Analytics\data\processed\clean_monthly_sip_inflows.csv"
)

print(sip.head())
print(sip.shape)

print(
    sip.loc[
        sip["sip_inflow_crore"].idxmax()
    ]
)
# Out:
#         month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01-01             11517                       4.91
# 1  2022-02-01             11438                       4.93
# 2  2022-03-01             12328                       5.09
# 3  2022-04-01             11863                       5.48
# 4  2022-05-01             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN
# (48, 6)
# month                        2025-12-01
# sip_inflow_crore                  31002
# active_sip_accounts_crore          9.35
# new_sip_accounts_lakh               9.8
# sip_aum_lakh_crore                 15.9
# ...

# %%
txn = pd.read_csv(
    r"C:\Users\Saiashish\Desktop\Mutual-Fund-Analytics\data\processed\clean_investor_transactions.csv"
)

print(txn.shape)

print(
    txn["age_group"]
    .value_counts()
)

print(
    txn["gender"]
    .value_counts()
)

print(
    txn["city_tier"]
    .value_counts()
)
# Out:
# (32778, 13)
# age_group
# 26-35    13463
# 36-45     8146
# 18-25     4916
# 46-55     3779
# 56+       2474
# Name: count, dtype: int64
# gender
# Male      21809
# Female    10969
# Name: count, dtype: int64
# city_tier
# T30    21719
# B30    11059
# Name: count, dtype: int64

# %%
portfolio = pd.read_csv(
    r"C:\Users\Saiashish\Desktop\Mutual-Fund-Analytics\data\processed\clean_portfolio_holdings.csv"
)

print(portfolio.shape)

print(
    portfolio["sector"]
    .value_counts()
    .head(20)
)
# Out:
# (322, 8)
# sector
# Banking           60
# IT                40
# Pharma            38
# Automobile        33
# Utilities         24
# Infrastructure    22
# FMCG              21
# Telecom           15
# Diversified       14
# Energy            13
# Cement            12
# NBFC              11
# Paints            10
# Consumer Goods     9
# Name: count, dtype: int64

# %%
folios = pd.read_csv(
    r"C:\Users\Saiashish\Desktop\Mutual-Fund-Analytics\data\processed\clean_industry_folio_count.csv"
)

print(folios.head())

print(folios.shape)
# Out:
#         month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01-01               13.26                 9.28               1.86
# 1  2022-04-01               13.91                 9.74               1.95
# 2  2022-07-01               13.85                 9.69               1.94
# 3  2022-10-01               14.12                 9.88               1.98
# 4  2023-01-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# 3                 0.85                 1.41
# 4                 0.89                 1.48
# (21, 6)
